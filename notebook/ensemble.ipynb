# %%
import pandas as pd
from pathlib import Path
output_dir = Path('../output/0113_211002/')
df1 = pd.read_csv(output_dir / 'submission.csv')
df1
# Out:
#      recording_id        s0        s1        s2        s3        s4        s5  \
# 0       000316da7  2.842965  0.758299 -1.364578  6.333678 -2.714042  1.228868
# 1       003bc2cb2 -1.225317  2.419990 -1.519536  1.904812 -1.353197 -1.490834
# 2       0061c037e  1.530443  0.206630 -2.328141  2.705436 -3.704833  0.998928
# 3       010eb14d3  8.383988 -0.094486 -2.716629  1.151224  0.007556 -1.389037
# 4       011318064 -0.178048  0.714060 -0.583283  3.671145 -2.633467 -0.361054
# ...           ...       ...       ...       ...       ...       ...       ...
# 1987    ff68f3ac3  0.977486 -1.099720 -1.717755  3.051586 -0.988308  7.171747
# 1988    ff973e852 -2.051708 -1.178194 -3.732901  2.183784 -4.633633 -0.368126
# 1989    ffa5cf6d6 -1.729274  1.164270 -2.060347  6.796323 -2.076683 -0.249202
# 1990    ffa88cbb8  0.580046  3.193977 -1.666270  8.005827 -4.518783  0.363475
# 1991    ffda5d7b3 -1.155973  0.516789  8.619883  4.697904 -2.512311  0.186493
#
# ...

# %%
df2 = pd.read_csv('../output/0110_121231/submission.csv')
df2
# Out:
#      recording_id        s0        s1        s2        s3        s4        s5  \
# 0       000316da7  2.351742  0.826792 -2.062728  7.602370 -1.431079  1.680464
# 1       003bc2cb2 -0.835879  1.477018 -1.408755  2.426591 -0.977448 -1.480095
# 2       0061c037e -0.565649  0.715468 -3.515926  2.643625 -4.443957  0.139397
# 3       010eb14d3  9.108768 -0.027517 -1.639629 -0.350859  0.304046 -1.797294
# 4       011318064 -1.135683  0.502137 -1.679157  4.308981 -1.664245  0.373851
# ...           ...       ...       ...       ...       ...       ...       ...
# 1987    ff68f3ac3  2.244993 -1.562125 -1.505134  2.256997 -0.822467  6.142549
# 1988    ff973e852 -3.343232 -2.295410 -5.291384  1.301954 -4.108094 -0.212701
# 1989    ffa5cf6d6 -1.576437 -0.573984 -3.385817  7.091048 -2.560141  0.254637
# 1990    ffa88cbb8 -0.041256  4.275039 -1.918688  7.571798 -2.879300 -0.048030
# 1991    ffda5d7b3 -0.700754 -0.028344  8.707348  5.594141 -2.884145 -0.533946
#
# ...

# %%
sub = df1.copy()

# %%
df2.iloc[:, 1:].values.shape
# Out:
# (1992, 24)

# %%
import numpy as np
sub.iloc[:, 1:] = np.mean([df1.iloc[:, 1:].values, df2.iloc[:, 1:].values], axis=0)
sub
# Out:
#      recording_id        s0        s1        s2        s3        s4        s5  \
# 0       000316da7  2.597353  0.792546 -1.713653  6.968024 -2.072561  1.454666
# 1       003bc2cb2 -1.030598  1.948504 -1.464146  2.165702 -1.165323 -1.485464
# 2       0061c037e  0.482397  0.461049 -2.922033  2.674530 -4.074395  0.569163
# 3       010eb14d3  8.746378 -0.061002 -2.178129  0.400183  0.155801 -1.593165
# 4       011318064 -0.656866  0.608099 -1.131220  3.990063 -2.148856  0.006398
# ...           ...       ...       ...       ...       ...       ...       ...
# 1987    ff68f3ac3  1.611240 -1.330923 -1.611445  2.654292 -0.905387  6.657148
# 1988    ff973e852 -2.697470 -1.736802 -4.512142  1.742869 -4.370863 -0.290413
# 1989    ffa5cf6d6 -1.652856  0.295143 -2.723082  6.943686 -2.318412  0.002718
# 1990    ffa88cbb8  0.269395  3.734508 -1.792479  7.788812 -3.699042  0.157722
# 1991    ffda5d7b3 -0.928363  0.244223  8.663615  5.146022 -2.698228 -0.173726
#
# ...

# %%
sub.to_csv(output_dir / "submission2.csv", index=False)
